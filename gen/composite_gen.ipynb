# %%
from astropy.table import Table
import numpy as np
import argparse
from jax import jit
import itertools
from scipy import interpolate

from Payne.jax.genmod import GenMod
from runUTPcomp import getdata

import matplotlib
matplotlib.use('AGG')
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.gridspec as gridspec
from matplotlib.ticker import MaxNLocator

import os
import csv
# %matplotlib inline

# %%
specNN = './models/specNN/modV0_spec_LinNet_R42K_WL510_535_wvt.h5'
photNN = './models/photNN/'
NNtype = 'LinNet'
mistNN = './models/mistNN/mistyNN_2.3_v256_v0.h5'
SBlib  = './models/specNN/c3k_v1.3.sed_r500.h5'

def planck(wav, T):
    h = 6.626e-34
    c = 3.0e+8
    k = 1.38e-23

    wave_i = wav*(1E-10)
    a = 2.0*h*c**2
    b = h*c/(wave_i*k*T)
    intensity = a/ ( (wave_i**5) * (np.exp(b) - 1.0) )
    return intensity

from scipy import constants
speedoflight = constants.c / 1000.0

# useful constants
# speedoflight = 2.997924e+10
speedoflight_kms = 2.997924e+5
speedoflight_nms = 2.997924e+17
lsun = 3.846e33
pc = 3.085677581467192e18  # in cm
jansky_cgs = 1e-23
# value to go from L_sun to erg/s/cm^2 at 10pc
log_rsun_cgs = np.log10(6.955) + 10.0
log_lsun_cgs = np.log10(lsun)
log4pi = np.log10(4 * np.pi)

rng = np.random.default_rng()

# %%
# make spectral prediction
data_p = getdata(spec='synth_spec_RV115.csv', phot='synth_phot_g2.0.csv')
data_s = getdata(spec='synth_spec_RV85.csv', phot='synth_phot_g2.0.csv')

# make sure the wavelengths are the same
print(np.where(data_p['spec']['obs_wave'] != data_s['spec']['obs_wave']))
waves = data_p['spec']['obs_wave']
# Out:
# (array([], dtype=int64),)

# %%
logr_p = 0.2
logr_s = 0.2

Teff_p = 9500
Teff_s = 9500

radius_p = 10.0**logr_p
radius_s = 10.0**logr_s

R = (
    (planck(waves,Teff_p) * radius_p**2.0) / 
    (planck(waves,Teff_s) * radius_s**2.0)
     )

speccomp = (data_p['spec']['obs_flux'] + R * data_s['spec']['obs_flux']) / (1.0 + R)
speccomp[:5]
# Out:
# <Column name='flux' dtype='float64' length=5>
# 0.9376659212686704
# 0.9337809003983912
# 0.9277898743237063
# 0.9224550329328157
# 0.9203269743335203

# %%
# sanity checks
print(np.where(R<0))
print(np.where(R<1))
# Out:
# (array([], dtype=int64),)
# (array([], dtype=int64),)

# %%
# add noise, setting seed for reproducibility
np.random.seed(0)

# mu and sigma come from hectochelle data:
# file: data_ngc6819_2010.0921_ngc6819_sep2010_1.7137.h5
# target id: 2076392838230907392
mu, sigma = 0.055402016862253524, 0.004453214396949145
noise = np.random.normal(mu, sigma, len(speccomp))
speccomp = speccomp + noise
print(speccomp[:5])
# Out:
#        flux
# ------------------
# 1.0009236414349592
# 0.9909649031019887
# 0.9875504212676205
# 0.9878362276517786
# 0.9840456273246471

# %%
fig, ax = plt.subplots()

ax.plot(waves, speccomp, ls='-',lw=1,c='k',zorder=1)
# ax.plot(data_p['spec']['obs_wave'], data_p['spec']['obs_flux']+flux2_interp, ls='-',lw=0.5,c='C3',zorder=0)
# ax.plot(waves, data_p['spec']['obs_flux'], ls='-',lw=1,c='C0',zorder=0)
# ax.plot(waves, data_s['spec']['obs_flux'], ls='-',lw=1,c='C1',zorder=0)

ax.set_xlabel(r'Wavelength ($\AA$)')
ax.set_ylabel(r'Brightness (arbitrary units)')

ax.set_xlim(5160,5190)
plt.savefig('synthetic_spec2.1_mgtriplet.png', dpi=300)

# %%
# make phot prediction
for i in data_p['phot'].keys():
    print(i)

phot_p = [data_p['phot'][xx][0] for xx in data_p['phot'].keys()]
phot_s = [data_s['phot'][xx][0] for xx in data_s['phot'].keys()]
print(phot_p, len(phot_p))

photcomp = (
    [-2.5 * np.log10( 10.0**(-0.4 * m_p) + 10.0**(-0.4 * m_s) )
     for m_p,m_s in zip(phot_p,phot_s)
     ] 
)

WAVE_d = {'GaiaDR3_G': 6217.59,
        'GaiaDR3_BP': 5109.71,
        'GaiaDR3_RP': 7769.02,
        '2MASS_J': 12350.0,
        '2MASS_H': 16620.0,
        '2MASS_Ks': 21590.0,
        'PS_g': 4775.6,
        'PS_r': 6129.5,
        'PS_i': 7484.6,
        'PS_z': 8657.8
       }

WAVE = np.array([ii for ii in WAVE_d.values()])
print(WAVE)
# (len(WAVE_d.values()),
# len(photcomp))
# Out:
# GaiaDR3_G
# GaiaDR3_BP
# GaiaDR3_RP
# 2MASS_J
# 2MASS_H
# 2MASS_Ks
# PS_g
# PS_r
# PS_i
# PS_z
# [8.132808954239295, 8.31470263534703, 7.812458754605544, 7.462222279086759, 7.383318017884784, 7.332164699494282, 8.28640229653303, 8.181958626875186, 8.157889889713768, 8.169321459587083] 10
# [ 6217.59  5109.71  7769.02 12350.   16620.   21590.    4775.6   6129.5
#   7484.6   8657.8 ]

# %%
# make some errors (taken from the known SB2 Gaia DR3 2076392838230907392)
emags = [0.05000091916311386,
         0.05004763662644478,
         0.050012894094444295,
         0.07733692547677395,
         0.08683893326204858,
         0.10121264701645077,
         0.020829461749839007,
         0.02065512096136038,
         0.020870045165005097,
         0.020915354323712318
        ]

# %%
fig, ax = plt.subplots()

for wavelength, mag, err in zip(WAVE, photcomp, emags):
    ax.scatter(wavelength/1E+4, mag, s=5, c='k',zorder=0)
    ax.errorbar(wavelength/1E+4, mag, yerr=err, c='C3',zorder=1)

ax.scatter(WAVE/1E+4, phot_p, s=5, c='C0', zorder=1)
ax.scatter(WAVE/1E+4, phot_s, s=5, c='C1', zorder=1)

ax.set_xlabel(r'$\lambda$ ($\mu$m)')
ax.set_ylabel(r'Mag.')
# Out:
# Text(0, 0.5, 'Mag.')

# %%
# output composite spectrum to csv
with open(f'synth_speccomp.csv','w') as out:
    csv_out=csv.writer(out)
    csv_out.writerow(['wave', 'flux', 'eflux'])

    for row in zip(waves, speccomp+noise, noise):
        # print(row)
        csv_out.writerow(row)
print(f'synthetic composite spectrum output to /etc/demo_smes/synth_speccomp.csv')
# Out:
# synthetic composite spectrum output to /etc/demo_smes/synth_speccomp.csv

# %%
# output composite photometry to csv
with open(f'synth_photcomp.csv','w') as out:
    csv_out=csv.writer(out)
    csv_out.writerow(['band', 'mag', 'emag'])

    for row in zip(WAVE_d.keys(), photcomp, emags):
        # print(row)
        csv_out.writerow(row)
print(f'synthetic composite photometry output to /etc/demo_smes/synth_photcomp.csv')
# Out:
# synthetic composite photometry output to /etc/demo_smes/synth_photcomp.csv

# %%
Table.read('synth_photcomp.csv')[:5]
# Out:
# <Table length=5>
#    band           mag                 emag
#   str10         float64             float64
# ---------- ------------------ --------------------
#  GaiaDR3_G  7.854314352127041  0.05000091916311386
# GaiaDR3_BP   8.08541322470232  0.05004763662644478
# GaiaDR3_RP  7.477306673095221 0.050012894094444295
#    2MASS_J  7.047103868815025  0.07733692547677395
#    2MASS_H 6.9071665579954376  0.08683893326204858

# %%
# test the getddata function on the composite spec & phot I made above
from runscripts.runUTPbinary_synth import getdata as getdata_synth
test_data = getdata_synth()
test_data
# Out:
# {'spec': {'obs_wave': <Column name='wave' dtype='float64' length=3729>
#    5160.033583244636
#    5160.069695358896
#    5160.105807428577
#    5160.141919453268
#    5160.178031432559
#    5160.214143366036
#   5160.2502552532915
#    5160.286367093913
#   5160.3224788874895
#    5160.358590633609
#    5160.394702331858
#    5160.430813981828
#      5160.4669255831
#    5160.503037135267
#    5160.539148637912
#    5160.575260090626
#   5160.6113714929925
#    5160.647482844599
#     5160.68359414503
#    5160.719705393872
#    5160.755816590713
#    5160.791927735134
#                  ...
#    5289.348165346953
#    5289.380496583505
#    5289.412825955153
#     5289.44515346169
#    5289.477479102911
#    5289.509802878617
#    5289.542124788601
#    5289.574444832661
#    5289.606763010596
#    5289.639079322204
#    5289.671393767286
#   5289.7037063456355
#   5289.7360170570555
#    5289.768325901346
#    5289.800632878305
#    5289.832937987731
#     5289.86524122943
#    5289.897542603198
#    5289.929842108839
#    5289.962139746154
#   5289.9944355149455,
#   'obs_flux': <Column name='flux' dtype='float64' length=3729>
#   1.0802089405937765
#   1.0735574043853071
#   1.0753929460265312
#    1.080358422644705
#    1.078317716088982
#   1.0655487141963693
#    1.074038253709133
#   1.0686507003086854
#   1.0676706913688279
#   1.0678979800843942
#    1.063765902310823
#   1.0659032567034386
#   1.0587017666173175
#   1.0519590417978621
#    1.050435764960085
#   1.0473900294033374
#   1.0475678199391534
#   1.0272392212901273
#   1.0040322411437772
#   0.9602706670237305
#   0.9092902413679097
#   0.8923206958205802
#                  ...
#    1.182301859729888
#   1.1897565826211713
#   1.1853423472151003
#    1.187737008043049
#   1.1817369006248755
#   1.1878722053262132
#   1.1980078348563712
#   1.1856904055453532
#   1.1897293949024819
#   1.1958065900479324
#   1.1934190409605785
#   1.1929124687481525
#   1.1873731352433692
#   1.1869280761919179
#    1.193334324984318
#   1.1912414568631184
#   1.1931967622302957
#   1.1939646607483636
#   1.1895039836616028
#   1.1937073110376228
#    1.198201324884071,
#   'obs_eflux': <Column name='eflux' dtype='float64' length=3729>
#    0.06325772016628864
#    0.05718400270359742
#    0.05976054694391419
#    0.06538119471896288
#    0.06371865299112676
#    0.05104998893776795
#    0.05963296428155311
#    0.05472799076318018
#    0.05494236118540989
#    0.05723050002245123
#   0.056043473767135116
#    0.06187820858056277
#    0.05879108101649954
#    0.05594386179744841
#    0.05737863500059184
#    0.05688794018080893
#    0.06205547130101941
#    0.05448840312839857
#     0.0567961744584651
#    0.05159854541962216
#    0.04403300585911666
#    0.05831272060158221
#                    ...
#     0.0492775024186041
#      0.058176414836352
#    0.05466904123213637
#    0.05724837975018728
#    0.05089275464139043
#     0.0564929885134979
#    0.06614471855520543
#    0.05336593263766936
#    0.05681546648986038
#    0.06210662927848358
#    0.05879404872636051
#   0.057325295518079744
#   0.050887841199829247
#    0.04971264192936726
#    0.05563996297636478
#    0.05333912828218972
#    0.05531714655028926
#    0.05631785012382592
#   0.052389738671821194
#    0.05760236357127485
#    0.06367856603882635},
#  'phot': {'GaiaDR3_G': [0.5621511158198917, 0.05000091916311386],
#   'GaiaDR3_BP': [0.7683125634784134, 0.05004763662644478],
#   'GaiaDR3_RP': [0.2107262510344232, 0.050012894094444295],
#   '2MASS_J': [-0.18603254430047844, 0.07733692547677395],
#   '2MASS_H': [-0.300139395332607, 0.08683893326204858],
#   '2MASS_Ks': [-0.35535683321118866, 0.10121264701645077],
#   'PS_g': [0.7485720601952955, 0.020829461749839007],
#   'PS_r': [0.6086221030325323, 0.02065512096136038],
#   'PS_i': [0.5583370421174051, 0.020870045165005097],
#   'PS_z': [0.5573378621724925, 0.020915354323712318]},
#  'parallax': [7.2301, 0.0486],
#  'RVest': 7.5,
#  'Avest': 0.09}

# %%
# test the getdata function on mist isochrone implementation
from runscripts.runUTPbinary_mist import getdata as getdata_mist
test_data = getdata_mist()
test_data

# %%
# read in the composite spectrum I generated above
synth_spec = Table.read('data/synth_speccomp.csv')
wave = synth_spec['wave']
flux = synth_spec['flux']
eflux = synth_spec['eflux']

# check for nans
print(f'nans in wavelength:\n{np.where(np.isnan(wave) == True)}\n')
print(f'nans in flux:\n{np.where(np.isnan(flux) == True)}\n')
print(f'nans in eflux:\n{np.where(np.isnan(eflux) == True)}\n')

# check for 0's in flux and eflux
print(f'0\'s in flux:\n{flux[flux < 0.05]}\n')
print(f'0\'s in eflux:\n{eflux[eflux < 0.04]}')
# Out:
# nans in wavelength:
# (array([], dtype=int64),)
#
# nans in flux:
# (array([], dtype=int64),)
#
# nans in eflux:
# (array([], dtype=int64),)
#
# 0's in flux:
# flux
# ----
#
# 0's in eflux:
# eflux
# -----

# %%
# plot the composite spectrum
fig, ax = plt.subplots()
ax.plot(wave, flux, lw=0.5, c='k')

# ax.set_xlim(5160, 5190)

# ax.set_xticks([])
# ax.set_yticks([])

# plt.savefig('Synthetic-Spectrum-Clean.png', dpi=500)

# %%
WAVE_d = {'GaiaDR3_G': 6217.59,
        'GaiaDR3_BP': 5109.71,
        'GaiaDR3_RP': 7769.02,
        '2MASS_J': 12350.0,
        '2MASS_H': 16620.0,
        '2MASS_Ks': 21590.0,
        'PS_g': 4775.6,
        'PS_r': 6129.5,
        'PS_i': 7484.6,
        'PS_z': 8657.8
       }

WAVE = np.array([ii for ii in WAVE_d.values()])

# read in the composite photometry I generated above
synth_phot = Table.read('data/synth_photcomp.csv')
synth_phot

# check for nans
# print(f'nans in wavelength:\n{np.where(np.isnan(wave) == True)}\n')
# print(f'nans in flux:\n{np.where(np.isnan(flux) == True)}\n')
# print(f'nans in eflux:\n{np.where(np.isnan(eflux) == True)}\n')

# check for 0's in flux and eflux
# print(f'0\'s in flux:\n{flux[flux < 0.05]}\n')
# print(f'0\'s in eflux:\n{eflux[eflux < 0.04]}')
# Out:
# <Table length=10>
#    band            mag                  emag
#   str10          float64              float64
# ---------- -------------------- --------------------
#  GaiaDR3_G   0.5621511158198917  0.05000091916311386
# GaiaDR3_BP   0.7683125634784134  0.05004763662644478
# GaiaDR3_RP   0.2107262510344232 0.050012894094444295
#    2MASS_J -0.18603254430047844  0.07733692547677395
#    2MASS_H   -0.300139395332607  0.08683893326204858
#   2MASS_Ks -0.35535683321118866  0.10121264701645077
#       PS_g   0.7485720601952955 0.020829461749839007
#       PS_r   0.6086221030325323  0.02065512096136038
#       PS_i   0.5583370421174051 0.020870045165005097
#       PS_z   0.5573378621724925 0.020915354323712318

# %%
fig, ax = plt.subplots()
ax.scatter(WAVE, synth_phot['mag'], lw=0.5, c='k',s=20)

ax.set_xlabel(r'$\lambda$ ($\mu$m)')
ax.set_ylabel(r'Mag.')
# ax.set_xlabel(

# ax.set_xlim(5160, 5190)

# ax.set_xticks([])
# ax.set_yticks([])

# plt.savefig('Synthetic-Photometry-Clean.png', dpi=500)
# Out:
# Text(0, 0.5, 'Mag.')

# %%
# relearning how interpolation works:
plt.plot(data_p['spec']['obs_wave'], flux2_interp)
plt.plot(data_p['spec']['obs_wave'], data_p['spec']['obs_flux'])
plt.plot(data_p['spec']['obs_wave'], flux2_interp+data_p['spec']['obs_flux'])
plt.xlim(5200,5215)
